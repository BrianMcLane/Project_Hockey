# %%
import pandas as pd
import numpy as np

# %%
game_skater_stats = "hockey_data/game_skater_stats.csv"
game_goalie_stats = "hockey_data/game_goalie_stats.csv"
player_info = "hockey_data/player_info.csv"

# %%
# Import the books.csv file as a DataFrame
game_skater_stats_df = pd.read_csv(game_skater_stats, encoding="utf-8")
game_goalie_stats_df = pd.read_csv(game_goalie_stats)
player_info_df = pd.read_csv(player_info)

# %%
game_skater_stats_df
# Out:
#            game_id  player_id  team_id  timeOnIce  assists  goals  shots  \
# 0       2016020045    8468513        4        955        1      0      0
# 1       2016020045    8476906        4       1396        1      0      4
# 2       2016020045    8474668        4        915        0      0      1
# 3       2016020045    8473512        4       1367        3      0      0
# 4       2016020045    8471762        4        676        0      0      3
# ...            ...        ...      ...        ...      ...    ...    ...
# 945825  2018030417    8475807        6        501        0      0      1
# 945826  2018030417    8475149        6       1062        0      0      2
# 945827  2018030417    8475745        6        913        0      0      2
# 945828  2018030417    8478443        6       1006        0      0      1
# 945829  2018030417    8478046        6        909        0      0      2
#
#         hits  powerPlayGoals  powerPlayAssists  ...  faceoffTaken  takeaways  \
# ...

# %%
game_skater_stats_df.dropna()
# Out:
#            game_id  player_id  team_id  timeOnIce  assists  goals  shots  \
# 0       2016020045    8468513        4        955        1      0      0
# 1       2016020045    8476906        4       1396        1      0      4
# 2       2016020045    8474668        4        915        0      0      1
# 3       2016020045    8473512        4       1367        3      0      0
# 4       2016020045    8471762        4        676        0      0      3
# ...            ...        ...      ...        ...      ...    ...    ...
# 945825  2018030417    8475807        6        501        0      0      1
# 945826  2018030417    8475149        6       1062        0      0      2
# 945827  2018030417    8475745        6        913        0      0      2
# 945828  2018030417    8478443        6       1006        0      0      1
# 945829  2018030417    8478046        6        909        0      0      2
#
#         hits  powerPlayGoals  powerPlayAssists  ...  faceoffTaken  takeaways  \
# ...

# %%
player_info_df
# Out:
#       player_id firstName      lastName nationality       birthCity  \
# 0       8466148    Marian         Hossa         SVK   Stará Lubovna
# 1       8465058    Michal      Rozsival         CZE          Vlasim
# 2       8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3       8466285     Brian      Campbell         CAN       Strathroy
# 4       8470607     Brent      Seabrook         CAN        Richmond
# ...         ...       ...           ...         ...             ...
# 3920    8479374      Adam     Mascherin         CAN           Maple
# 3921    8479403     Tyler       Parsons         USA      Mt. Clemas
# 3922    8480970    Marcus      Hogstrom         SWE            Sveg
# 3923    8477574    Parker        Milner         USA      Pittsburgh
# 3924    8477352      Ryan    Fitzgerald         USA      Boca Raton
#
#      primaryPosition            birthDate birthStateProvince  height  \
# 0                 RW  1979-01-12 00:00:00                NaN   6' 1"
# ...

# %%
game_skater_stats_df.dtypes
# Out:
# game_id                   int64
# player_id                 int64
# team_id                   int64
# timeOnIce                 int64
# assists                   int64
# goals                     int64
# shots                     int64
# hits                    float64
# powerPlayGoals            int64
# powerPlayAssists          int64
# penaltyMinutes            int64
# faceOffWins               int64
# faceoffTaken              int64
# takeaways               float64
# giveaways               float64
# shortHandedGoals          int64
# shortHandedAssists        int64
# blocked                 float64
# plusMinus                 int64
# evenTimeOnIce             int64
# shortHandedTimeOnIce      int64
# powerPlayTimeOnIce        int64
# dtype: object

# %%
game_skater_stats_df = game_skater_stats_df.loc[game_skater_stats_df['team_id'] == 16]
game_skater_stats_df
# Out:
#            game_id  player_id  team_id  timeOnIce  assists  goals  shots  \
# 18      2016020045    8466148       16        723        0      1      2
# 19      2016020045    8471769       16       1241        0      0      1
# 20      2016020045    8477929       16        652        0      1      1
# 21      2016020045    8466285       16       1068        1      0      0
# 22      2016020045    8470607       16       1294        3      0      0
# ...            ...        ...      ...        ...      ...    ...    ...
# 939363  2018021266    8479465       16        850        0      1      2
# 939364  2018021266    8473573       16       1175        0      0      4
# 939365  2018021266    8478440       16        969        1      0      5
# 939366  2018021266    8478055       16       1048        0      0      0
# 939367  2018021266    8476473       16       1010        0      0      2
#
#         hits  powerPlayGoals  powerPlayAssists  ...  faceoffTaken  takeaways  \
# ...

# %%
game_goalie_stats_df = game_goalie_stats_df.loc[game_goalie_stats_df['team_id'] == 16]
game_goalie_stats_df
# Out:
#           game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 2      2016020045    8470645       16       3598        0      0    0     27
# 32     2016020107    8470645       16       3608        0      0    0     32
# 179    2017021255    8475234       16       3496        0      0    0     34
# 189    2017021010    8475234       16       1640        0      0    0     10
# 190    2017021010    8476341       16       1823        0      0    0     21
# ...           ...        ...      ...        ...      ...    ...  ...    ...
# 56220  2018021255    8470645       16       1546        0      0    0      9
# 56226  2018021255    8470320       16       1993        0      0    0     26
# 56227  2018021255    8470645       16       1546        0      0    0      9
# 56250  2018021266    8470320       16       3582        0      0    0     49
# 56282  2018021266    8470320       16       3582        0      0    0     49
#
# ...

# %%
player_list = game_skater_stats_df["player_id"].unique()
player_list = list(player_list)
len(player_list)
# Out:
# 280

# %%
goalie_id = game_goalie_stats_df["player_id"].unique()
goalie_id = list(goalie_id)
len(goalie_id)
# Out:
# 29

# %%
player_list.extend(goalie_id)
len(player_list)
# Out:
# 309

# %%
boolean_series = player_info_df.player_id.isin(player_list) 

filtered_df = player_info_df[boolean_series]
filtered_df
# Out:
#       player_id  firstName  lastName nationality      birthCity  \
# 0       8466148     Marian     Hossa         SVK  Stará Lubovna
# 1       8465058     Michal  Rozsival         CZE         Vlasim
# 3       8466285      Brian  Campbell         CAN      Strathroy
# 4       8470607      Brent  Seabrook         CAN       Richmond
# 5       8474668       Dale     Weise         CAN       Winnipeg
# ...         ...        ...       ...         ...            ...
# 3809    8479542    Brandon     Hagel         CAN      Saskatoon
# 3833    8479523      Lucas  Carlsson         SWE          Gävle
# 3839    8480814    Nicolas   Beaudin         CAN    Chateauguay
# 3893    8479657  Alexandre    Fortin         CAN     Blainville
# 3903    8480954      Jacob   Nilsson         SWE         Morrum
#
#      primaryPosition            birthDate birthStateProvince  height  \
# 0                 RW  1979-01-12 00:00:00                NaN   6' 1"
# ...
